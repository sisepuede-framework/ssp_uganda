# %%
import copy
import datetime as dt
import importlib # needed so that we can reload packages
import matplotlib.pyplot as plt
import os, os.path
import numpy as np
import pandas as pd
import pathlib
import sys
import time
from typing import Union
import warnings
from datetime import datetime
warnings.filterwarnings("ignore")

##  IMPORT SISEPUEDE EXAMPLES AND TRANSFORMERS

from sisepuede.manager.sisepuede_examples import SISEPUEDEExamples
from sisepuede.manager.sisepuede_file_structure import SISEPUEDEFileStructure
import sisepuede.core.support_classes as sc
import sisepuede.transformers as trf
import sisepuede.utilities._plotting as spu
import sisepuede.utilities._toolbox as sf

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Initial Set up
#
# Make sure to edit the config yaml under croatia/config_files/croatia_config.yaml
#
# You can also create a new config yaml

# %%
# Set up dir paths

dir_cur = pathlib.Path(os.getcwd())
dir_ssp_modeling = dir_cur.parent
dir_project = dir_ssp_modeling.parent
dir_data = dir_ssp_modeling.joinpath("input_data")
dir_out= dir_ssp_modeling.joinpath("ssp_run/bau")
dir_scenario_mapping = dir_ssp_modeling.joinpath("scenario_mapping")
dir_config = dir_ssp_modeling.joinpath("config_files")
dir_transformations = dir_ssp_modeling.joinpath("transformations")
dir_misc = dir_ssp_modeling.joinpath("misc")
strategies_definitions_file_path = dir_transformations.joinpath("strategy_definitions.csv")
strategy_mapping_file_path = dir_misc.joinpath("strategy_mapping.yaml")

# %%
dir_scenario_mapping
# Out:
# PosixPath('/home/tony-ubuntu/decision_sciences/ssp_uganda/ssp_modeling/scenario_mapping')

# %%
from ssp_transformations_handler.GeneralUtils import GeneralUtils
from ssp_transformations_handler.TransformationUtils import TransformationYamlProcessor, StrategyCSVHandler

# Initialize general utilities
g_utils = GeneralUtils()

# %%
# Load config file, double check your parameters are correct

yaml_file_path = os.path.join(dir_config, "bau_calibrated_config.yaml")
config_params = g_utils.read_yaml(yaml_file_path)

country_name = config_params['country_name']
ssp_input_file_name = config_params['ssp_input_file_name']
ssp_transformation_cw = config_params['ssp_transformation_cw']
energy_model_flag = config_params['energy_model_flag']
set_lndu_reallocation_factor_to_zero_flag = config_params['set_lndu_reallocation_factor_to_zero']

# Print config parameters
print("Country name: ", country_name)
print("SSP input file name: ", ssp_input_file_name)
print("SSP transformation CW: ", ssp_transformation_cw)
print("Energy model flag: ", energy_model_flag)
print("Set lndu reallocation factor to zero flag: ", set_lndu_reallocation_factor_to_zero_flag)
# Out:
# Country name:  uganda
# SSP input file name:  best_BaU_input_df_20250605161834.csv
# SSP transformation CW:  ssp_uganda_transformation_cw_bau.xlsx
# Energy model flag:  False
# Set lndu reallocation factor to zero flag:  True

# %%
# Set up SSP objects

fp_data_base = dir_data.joinpath(ssp_input_file_name)

file_struct = SISEPUEDEFileStructure()

matt = file_struct.model_attributes
regions = sc.Regions(matt)
time_periods = sc.TimePeriods(matt)

# %%
##  BUILD BASE INPUTS
df_inputs_raw_complete = pd.read_csv(fp_data_base)

# pull example data to fill in gaps
examples = SISEPUEDEExamples()
df_inputs_example = examples.input_data_frame

# %% [markdown]
# ## Evolution gdp_mmm_usd BaU Scenario

# %%
df_inputs_raw_complete['gdp_mmm_usd'].tail()
# Out:
# 31    443.314127
# 32    483.212399
# 33    526.701514
# 34    574.104651
# 35    625.774069
# Name: gdp_mmm_usd, dtype: float64

# %%
df_inputs_raw_complete = df_inputs_raw_complete.sort_values("time_period")
df_inputs_raw_complete["gdp_mmm_usd_pct_change"] = df_inputs_raw_complete["gdp_mmm_usd"].pct_change() * 100

# %%
df_inputs_raw_complete[['time_period','gdp_mmm_usd','gdp_mmm_usd_pct_change']].tail()
# Out:
#     time_period  gdp_mmm_usd  gdp_mmm_usd_pct_change
# 31           31   443.314127                     9.0
# 32           32   483.212399                     9.0
# 33           33   526.701514                     9.0
# 34           34   574.104651                     9.0
# 35           35   625.774069                     9.0

# %%
plt.figure(figsize=(10,6))
plt.plot(df_inputs_raw_complete["time_period"], df_inputs_raw_complete["gdp_mmm_usd_pct_change"], marker='o', linestyle='-')

plt.xlabel("Time Period")
plt.ylabel("Annual Change in GDP (Billion US Dollars)")
plt.title("Annual Variation in GDP (Absolute Change)")
plt.axhline(0, color='black', linestyle='--')  # Línea base
plt.grid(True)
plt.tight_layout()
plt.show()

plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df_inputs_raw_complete["time_period"], df_inputs_raw_complete["gdp_mmm_usd"], marker='o')

plt.show()

# %% [markdown]
# #  Let's try building transformations using this

# %%
transformers = trf.transformers.Transformers(
    {},
    df_input = df_inputs_raw_complete,
)

# %% [markdown]
# ##  Instantiate some transformations. Make sure to run this cell to create the transformations folder for the first time or if you wish to overwrite

# %%
# set an ouput path and instantiate
if not dir_transformations.exists():
    trf.instantiate_default_strategy_directory(
        transformers,
        dir_transformations,
    )
else:
    print(f"Directory {dir_transformations} already exists. Skipping instantiation.")
# Out:
# Directory /home/tony-ubuntu/decision_sciences/ssp_uganda/ssp_modeling/transformations already exists. Skipping instantiation.

# %% [markdown]
# ##  --HERE, CUSTOMIZE YOUR TRANSFORMATIONS AND STRATEGIES--

# %% [markdown]
# ### Customizing transformations and strategies files using TransformationUtils.py classes

# %%
# Generate new transformation files based on the excel mapping file. 
# Make sure to have the most updated format for the excel file, check the one used in this notebook for reference.

cw_file_path = os.path.join(dir_scenario_mapping, ssp_transformation_cw)
print(cw_file_path)
excel_yaml_handler = TransformationYamlProcessor(scenario_mapping_excel_path=cw_file_path, yaml_dir_path=dir_transformations)
# Out:
# /home/tony-ubuntu/decision_sciences/ssp_uganda/ssp_modeling/scenario_mapping/ssp_uganda_transformation_cw_bau.xlsx

# %%
# This creates transformation yaml files for each strategy in the excel file
excel_yaml_handler.process_yaml_files()
# Out:
# YAML file transformation_agrc_inc_conservation_agriculture.yaml already exist for strategy strategy_NDC. Please check it manually.
# YAML file transformation_agrc_inc_conservation_agriculture.yaml already exist for strategy strategy_NZ. Please check it manually.
# YAML file transformation_inen_shift_fuel_heat.yaml already exist for strategy strategy_NZ. Please check it manually.
# YAML file transformation_lsmm_inc_management_cattle_pigs.yaml already exist for strategy strategy_NDC. Please check it manually.
# YAML file transformation_lsmm_inc_management_cattle_pigs.yaml already exist for strategy strategy_NZ. Please check it manually.
# YAML file transformation_lsmm_inc_management_other.yaml already exist for strategy strategy_NDC. Please check it manually.
# YAML file transformation_lsmm_inc_management_other.yaml already exist for strategy strategy_NZ. Please check it manually.
# YAML file transformation_lsmm_inc_management_poultry.yaml already exist for strategy strategy_NDC. Please check it manually.
# YAML file transformation_lsmm_inc_management_poultry.yaml already exist for strategy strategy_NZ. Please check it manually.
# YAML file transformation_lvst_dec_enteric_fermentation.yaml already exist for strategy strategy_NZ. Please check it manually.
# YAML file transformation_pflo_inc_ind_ccs.yaml already exist for strategy strategy_NZ. Please check it manually.
# YAML file transformation_trns_shift_mode_regional.yaml already exist for strategy strategy_NDC. Please check it manually.
# YAML file transformation_trns_shift_mode_regional.yaml already exist for strategy strategy_NZ. Please check it manually.
# YAML file transformation_wali_inc_treatment_industrial.yaml already exist for strategy strategy_NDC. Please check it manually.
# YAML file transformation_wali_inc_treatment_industrial.yaml already exist for strategy strategy_NZ. Please check it manually.
# YAML file transformation_wali_inc_treatment_rural.yaml already exist for strategy strategy_NDC. Please check it manually.
# YAML file transformation_wali_inc_treatment_rural.yaml already exist for strategy strategy_NZ. Please check it manually.
# YAML file transformation_wali_inc_treatment_urban.yaml already exist for strategy strategy_NDC. Please check it manually.
# YAML file transformation_wali_inc_treatment_urban.yaml already exist for strategy strategy_NZ. Please check it manually.
# YAML file transformation_waso_inc_anaerobic_and_compost.yaml already exist for strategy strategy_NZ. Please check it manually.

# %%
# Load the transformations per strategy dictionary so we can pass it to the strategy handler
# You can also check here if the transformations in each strategy are correct
transformation_per_strategy_dict = excel_yaml_handler.get_transformations_per_strategy_dict()
transformation_per_strategy_dict
# Out:
# {'strategy_NDC': ['TX:AGRC:DEC_CH4_RICE_STRATEGY_NDC',
#   'TX:AGRC:INC_CONSERVATION_AGRICULTURE_STRATEGY_NDC',
#   'TX:AGRC:INC_PRODUCTIVITY_STRATEGY_NDC',
#   'TX:ENTC:DEC_LOSSES_STRATEGY_NDC',
#   'TX:ENTC:TARGET_CLEAN_HYDROGEN_STRATEGY_NDC',
#   'TX:ENTC:TARGET_RENEWABLE_ELEC_STRATEGY_NDC',
#   'TX:INEN:INC_EFFICIENCY_ENERGY_STRATEGY_NDC',
#   'TX:INEN:INC_EFFICIENCY_PRODUCTION_STRATEGY_NDC',
#   'TX:IPPU:DEC_CLINKER_STRATEGY_NDC',
#   'TX:IPPU:DEC_DEMAND_STRATEGY_NDC',
#   'TX:IPPU:DEC_HFCS_STRATEGY_NDC',
#   'TX:LNDU:DEC_DEFORESTATION_STRATEGY_NDC',
#   'TX:LNDU:INC_REFORESTATION_STRATEGY_NDC',
#   'TX:LSMM:INC_CAPTURE_BIOGAS_STRATEGY_NDC',
#   'TX:LSMM:INC_MANAGEMENT_CATTLE_PIGS_STRATEGY_NDC',
#   'TX:LSMM:INC_MANAGEMENT_OTHER_STRATEGY_NDC',
#   'TX:LSMM:INC_MANAGEMENT_POULTRY_STRATEGY_NDC',
#   'TX:LVST:INC_PRODUCTIVITY_STRATEGY_NDC',
#   'TX:SOIL:DEC_LIME_APPLIED_STRATEGY_NDC',
#   'TX:SOIL:DEC_N_APPLIED_STRATEGY_NDC',
#   'TX:TRDE:DEC_DEMAND_STRATEGY_NDC',
#   'TX:TRNS:INC_EFFICIENCY_ELECTRIC_STRATEGY_NDC',
#   'TX:TRNS:INC_EFFICIENCY_NON_ELECTRIC_STRATEGY_NDC',
#   'TX:TRNS:SHIFT_FUEL_MARITIME_STRATEGY_NDC',
#   'TX:TRNS:SHIFT_FUEL_MEDIUM_DUTY_STRATEGY_NDC',
#   'TX:TRNS:SHIFT_MODE_FREIGHT_STRATEGY_NDC',
#   'TX:TRNS:SHIFT_MODE_PASSENGER_STRATEGY_NDC',
#   'TX:TRNS:SHIFT_MODE_REGIONAL_STRATEGY_NDC',
#   'TX:TRWW:INC_COMPLIANCE_SEPTIC_STRATEGY_NDC',
#   'TX:WALI:INC_TREATMENT_INDUSTRIAL_STRATEGY_NDC',
#   'TX:WALI:INC_TREATMENT_RURAL_STRATEGY_NDC',
#   'TX:WALI:INC_TREATMENT_URBAN_STRATEGY_NDC',
#   'TX:WASO:DEC_CONSUMER_FOOD_WASTE_STRATEGY_NDC',
#   'TX:WASO:INC_CAPTURE_BIOGAS_STRATEGY_NDC',
#   'TX:WASO:INC_ENERGY_FROM_BIOGAS_STRATEGY_NDC',
#   'TX:WASO:INC_ENERGY_FROM_INCINERATION_STRATEGY_NDC',
#   'TX:WASO:INC_LANDFILLING_STRATEGY_NDC',
#   'TX:WASO:INC_RECYCLING_STRATEGY_NDC'],
#  'strategy_NZ': ['TX:AGRC:DEC_CH4_RICE_STRATEGY_NZ',
#   'TX:AGRC:DEC_EXPORTS_STRATEGY_NZ',
#   'TX:AGRC:DEC_LOSSES_SUPPLY_CHAIN_STRATEGY_NZ',
#   'TX:AGRC:INC_CONSERVATION_AGRICULTURE_STRATEGY_NZ',
#   'TX:AGRC:INC_PRODUCTIVITY_STRATEGY_NZ',
#   'TX:CCSQ:INC_CAPTURE_STRATEGY_NZ',
#   'TX:ENTC:DEC_LOSSES_STRATEGY_NZ',
#   'TX:ENTC:TARGET_CLEAN_HYDROGEN_STRATEGY_NZ',
#   'TX:ENTC:TARGET_RENEWABLE_ELEC_STRATEGY_NZ',
#   'TX:FGTV:DEC_LEAKS_STRATEGY_NZ',
#   'TX:FGTV:INC_FLARE_STRATEGY_NZ',
#   'TX:INEN:INC_EFFICIENCY_ENERGY_STRATEGY_NZ',
#   'TX:INEN:INC_EFFICIENCY_PRODUCTION_STRATEGY_NZ',
#   'TX:INEN:SHIFT_FUEL_HEAT_STRATEGY_NZ',
#   'TX:IPPU:DEC_CLINKER_STRATEGY_NZ',
#   'TX:IPPU:DEC_DEMAND_STRATEGY_NZ',
#   'TX:IPPU:DEC_HFCS_STRATEGY_NZ',
#   'TX:IPPU:DEC_N2O_STRATEGY_NZ',
#   'TX:IPPU:DEC_OTHER_FCS_STRATEGY_NZ',
#   'TX:IPPU:DEC_PFCS_STRATEGY_NZ',
#   'TX:LNDU:DEC_DEFORESTATION_STRATEGY_NZ',
#   'TX:LNDU:INC_REFORESTATION_STRATEGY_NZ',
#   'TX:LSMM:INC_CAPTURE_BIOGAS_STRATEGY_NZ',
#   'TX:LSMM:INC_MANAGEMENT_CATTLE_PIGS_STRATEGY_NZ',
#   'TX:LSMM:INC_MANAGEMENT_OTHER_STRATEGY_NZ',
#   'TX:LSMM:INC_MANAGEMENT_POULTRY_STRATEGY_NZ',
#   'TX:LVST:DEC_ENTERIC_FERMENTATION_STRATEGY_NZ',
#   'TX:LVST:DEC_EXPORTS_STRATEGY_NZ',
#   'TX:LVST:INC_PRODUCTIVITY_STRATEGY_NZ',
#   'TX:PFLO:INC_IND_CCS_STRATEGY_NZ',
#   'TX:SCOE:DEC_DEMAND_HEAT_STRATEGY_NZ',
#   'TX:SCOE:INC_EFFICIENCY_APPLIANCE_STRATEGY_NZ',
#   'TX:SCOE:SHIFT_FUEL_HEAT_STRATEGY_NZ',
#   'TX:SOIL:DEC_LIME_APPLIED_STRATEGY_NZ',
#   'TX:SOIL:DEC_N_APPLIED_STRATEGY_NZ',
#   'TX:TRDE:DEC_DEMAND_STRATEGY_NZ',
#   'TX:TRNS:INC_EFFICIENCY_ELECTRIC_STRATEGY_NZ',
#   'TX:TRNS:INC_EFFICIENCY_NON_ELECTRIC_STRATEGY_NZ',
#   'TX:TRNS:INC_OCCUPANCY_LIGHT_DUTY_STRATEGY_NZ',
#   'TX:TRNS:SHIFT_FUEL_LIGHT_DUTY_STRATEGY_NZ',
#   'TX:TRNS:SHIFT_FUEL_MARITIME_STRATEGY_NZ',
#   'TX:TRNS:SHIFT_FUEL_MEDIUM_DUTY_STRATEGY_NZ',
#   'TX:TRNS:SHIFT_FUEL_RAIL_STRATEGY_NZ',
#   'TX:TRNS:SHIFT_MODE_FREIGHT_STRATEGY_NZ',
#   'TX:TRNS:SHIFT_MODE_PASSENGER_STRATEGY_NZ',
#   'TX:TRNS:SHIFT_MODE_REGIONAL_STRATEGY_NZ',
#   'TX:TRWW:INC_CAPTURE_BIOGAS_STRATEGY_NZ',
#   'TX:TRWW:INC_COMPLIANCE_SEPTIC_STRATEGY_NZ',
#   'TX:WALI:INC_TREATMENT_INDUSTRIAL_STRATEGY_NZ',
#   'TX:WALI:INC_TREATMENT_RURAL_STRATEGY_NZ',
#   'TX:WALI:INC_TREATMENT_URBAN_STRATEGY_NZ',
#   'TX:WASO:DEC_CONSUMER_FOOD_WASTE_STRATEGY_NZ',
#   'TX:WASO:INC_ANAEROBIC_AND_COMPOST_STRATEGY_NZ',
#   'TX:WASO:INC_CAPTURE_BIOGAS_STRATEGY_NZ',
#   'TX:WASO:INC_ENERGY_FROM_BIOGAS_STRATEGY_NZ',
#   'TX:WASO:INC_ENERGY_FROM_INCINERATION_STRATEGY_NZ',
#   'TX:WASO:INC_LANDFILLING_STRATEGY_NZ',
#   'TX:WASO:INC_RECYCLING_STRATEGY_NZ'],
#  'strategy_BAU': ['TX:AGRC:INC_PRODUCTIVITY_STRATEGY_BAU',
#   'TX:LVST:INC_PRODUCTIVITY_STRATEGY_BAU']}

# %%
transformation_per_strategy_dict.keys()
# Out:
# dict_keys(['strategy_NDC', 'strategy_NZ', 'strategy_BAU'])

# %% [markdown]
# ### Creating new strategies
# - You can create new strategies from scratch.
# - You can also update existing ones.

# %%
# Creating new strategies by updating the strategy_definitions file.
# You can edit this to add yours, as many as you want.
csv_handler = StrategyCSVHandler(strategies_definitions_file_path, dir_transformations, strategy_mapping_file_path, transformation_per_strategy_dict)

#csv_handler.add_strategy(strategy_group='PFLO', description='NDC BaU', yaml_file_suffix='BaU')
csv_handler.add_strategy(strategy_group='PFLO', description='NDC', yaml_file_suffix='NDC')
csv_handler.add_strategy(strategy_group='PFLO', description='Net Zero', yaml_file_suffix='NZ')
csv_handler.add_strategy(strategy_group='PFLO', description='S BAU', yaml_file_suffix='BAU')
# Out:
# INFO: Strategy code PFLO:NDC already exists in the strategy definitions. Strategy will be updated...
# Updated row with strategy_code PFLO:NDC
# INFO: Strategy code PFLO:NZ already exists in the strategy definitions. Strategy will be updated...
# Updated row with strategy_code PFLO:NZ
# INFO: Strategy code PFLO:BAU already exists in the strategy definitions. Strategy will be updated...
# Updated row with strategy_code PFLO:BAU

# %%
# Set up the strategy codes you wish to run in ssp
strategies_to_run = [0, 6003, 6004, 6005]

# %% [markdown]
# # Manual modification YAML

# %% [markdown]
# ## TX:LNDU:DEC_DEFORESTATION

# %%
import yaml

with open(os.path.join(dir_transformations, 'transformation_lndu_dec_deforestation_strategy_NZ.yaml'), 'r') as file:
    data = yaml.safe_load(file)


data['parameters']['magnitude'] = 0.9999999   


with open(os.path.join(dir_transformations, 'transformation_lndu_dec_deforestation_strategy_NZ.yaml'), 'w') as file:
    yaml.dump(data, file, sort_keys=False)

# %%
with open(os.path.join(dir_transformations, 'transformation_lndu_dec_deforestation_strategy_NDC.yaml'), 'r') as file:
    data = yaml.safe_load(file)


data['parameters']['magnitude'] = 0.996


with open(os.path.join(dir_transformations, 'transformation_lndu_dec_deforestation_strategy_NDC.yaml'), 'w') as file:
    yaml.dump(data, file, sort_keys=False)

# %% [markdown]
# ## TX:AGRC:INC_CONSERVATION_AGRICULTURE

# %%
with open(os.path.join(dir_transformations, 'transformation_agrc_inc_conservation_agriculture_strategy_NZ.yaml'), 'r') as file:
    data = yaml.safe_load(file)


data['parameters']['magnitude_burned'] = 0.8
data['parameters']['magnitude_removed'] = 0.8   


with open(os.path.join(dir_transformations, 'transformation_agrc_inc_conservation_agriculture_strategy_NZ.yaml'), 'w') as file:
    yaml.dump(data, file, sort_keys=False)

# %%
with open(os.path.join(dir_transformations, 'transformation_agrc_inc_conservation_agriculture_strategy_NDC.yaml'), 'r') as file:
    data = yaml.safe_load(file)


data['parameters']['magnitude_burned'] = 0.6
data['parameters']['magnitude_removed'] = 0.6   


with open(os.path.join(dir_transformations, 'transformation_agrc_inc_conservation_agriculture_strategy_NDC.yaml'), 'w') as file:
    yaml.dump(data, file, sort_keys=False)

# %% [markdown]
# ### We finished adding new transformation files and strategies so lets load them back

# %%
# then, you can load this back in after modifying (play around with it)
transformations = trf.Transformations(
    dir_transformations,
    transformers = transformers,
)
tab = transformations.attribute_transformation.table

# %%
#  build the strategies -- will export to path
t0 = time.time()
strategies = trf.Strategies(
    transformations,
    export_path = "transformations",
    prebuild = True,
)

t_elapse = sf.get_time_elapsed(t0)
print(f"Strategies defined at {strategies.transformations.dir_init} initialized in {t_elapse} seconds")
# Out:
# Strategies defined at /home/tony-ubuntu/decision_sciences/ssp_uganda/ssp_modeling/transformations initialized in 4.13 seconds

# %%
strategies.attribute_table
# Out:
#     strategy_id                      strategy_code  \
# 0             0                               BASE
# 1          1000                  AGRC:DEC_CH4_RICE
# 2          1001                   AGRC:DEC_EXPORTS
# 3          1002       AGRC:DEC_LOSSES_SUPPLY_CHAIN
# 4          1003  AGRC:INC_CONSERVATION_AGRICULTURE
# ..          ...                                ...
# 68         6002                           PFLO:ALL
# 69         6003                           PFLO:NDC
# 70         6004                            PFLO:NZ
# 71         6005                           PFLO:BAU
# 72         6006                           PFLO:ASP
#
#                                              strategy  \
# 0                                    Strategy TX:BASE
# 1   Singleton - Default Value - AGRC: Improve rice...
# 2   Singleton - Default Value - AGRC: Decrease Exp...
# 3   Singleton - Default Value - AGRC: Reduce suppl...
# 4   Singleton - Default Value - AGRC: Expand conse...
# ..                                                ...
# 68                                        All Actions
# 69                                                NDC
# 70                                                 NZ
# 71                                                BAU
# 72                                                ASP
#
#                             description  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 68  All actions (unique by transformer)
# 69                                  NDC
# 70                             Net Zero
# 71                                S BAU
# 72                                S ASP
#
#                          transformation_specification  baseline_strategy_id
# 0                                             TX:BASE                     1
# 1                                TX:AGRC:DEC_CH4_RICE                     0
# 2                                 TX:AGRC:DEC_EXPORTS                     0
# 3                     TX:AGRC:DEC_LOSSES_SUPPLY_CHAIN                     0
# 4                TX:AGRC:INC_CONSERVATION_AGRICULTURE                     0
# ..                                                ...                   ...
# 68  TX:AGRC:DEC_CH4_RICE|TX:AGRC:DEC_EXPORTS|TX:AG...                     0
# 69  TX:INEN:INC_EFFICIENCY_PRODUCTION_STRATEGY_NDC...                     0
# 70  TX:WASO:INC_RECYCLING_STRATEGY_NZ|TX:WALI:INC_...                     0
# 71  TX:LVST:INC_PRODUCTIVITY_STRATEGY_BAU|TX:AGRC:...                     0
# 72  TX:AGRC:INC_PRODUCTIVITY_STRATEGY_ASP|TX:LVST:...                     0
#
# [73 rows x 6 columns]

# %% [markdown]
# ##  Build our templates
# - let's use the default variable groupings for LHS

# %%
# Building excel templates, make sure to include the strategies ids in the strategies attribute as well as the baseline (0)
df_vargroups = examples("variable_trajectory_group_specification")

strategies.build_strategies_to_templates(
    df_trajgroup = df_vargroups,
    include_simplex_group_as_trajgroup = True,
    strategies = strategies_to_run,
)
# Out:
# starting strat 6003 with input shape (36, 2220)
# strat 6003 with output shape (36, 2220)
# here = 6003
# starting strat 6004 with input shape (36, 2220)
# strat 6004 with output shape (36, 2220)
# here = 6004
# starting strat 6005 with input shape (36, 2220)
# strat 6005 with output shape (36, 2220)
# here = 6005
# 0

# %% [markdown]
# # Finally, load SISEPUEDE so that we can run it

# %%
import sisepuede as si
# timestamp_str = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
ssp = si.SISEPUEDE(
    "calibrated",
    db_type = "csv",
    # id_str = f"sisepuede_run_2024-11-04T09:23:26.721580",
    initialize_as_dummy = not(energy_model_flag), # no connection to Julia is initialized if set to True
    regions = [country_name],
    strategies = strategies,
    try_exogenous_xl_types_in_variable_specification = True,
)
# Out:
# 2025-06-09 10:31:54,333 - INFO - Successfully initialized SISEPUEDEFileStructure.
# 2025-06-09 10:31:54,336 - WARNING - Missing key dict_dimensional_keys: key time_series not found. Tables that rely on the time_series will not have index checking.
# 2025-06-09 10:31:54,337 - INFO - 	Setting export engine to 'csv'.
# 2025-06-09 10:31:54,338 - WARNING - No index fields defined. Index field values will not be checked when writing to tables.
# 2025-06-09 10:31:54,338 - INFO - Successfully instantiated table ANALYSIS_METADATA
# 2025-06-09 10:31:54,339 - WARNING - No index fields found in ATTRIBUTE_DESIGN. Initializing index fields.
# 2025-06-09 10:31:54,339 - INFO - Successfully instantiated table ATTRIBUTE_DESIGN
# 2025-06-09 10:31:54,339 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES. Initializing index fields.
# 2025-06-09 10:31:54,340 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES
# 2025-06-09 10:31:54,341 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS. Initializing index fields.
# 2025-06-09 10:31:54,341 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS
# 2025-06-09 10:31:54,342 - WARNING - No index fields found in ATTRIBUTE_PRIMARY. Initializing index fields.
# 2025-06-09 10:31:54,342 - INFO - Successfully instantiated table ATTRIBUTE_PRIMARY
# 2025-06-09 10:31:54,343 - WARNING - No index fields found in ATTRIBUTE_STRATEGY. Initializing index fields.
# 2025-06-09 10:31:54,343 - INFO - Successfully instantiated table ATTRIBUTE_STRATEGY
# 2025-06-09 10:31:54,344 - WARNING - No index fields found in MODEL_BASE_INPUT_DATABASE. Initializing index fields.
# 2025-06-09 10:31:54,344 - INFO - Successfully instantiated table MODEL_BASE_INPUT_DATABASE
# 2025-06-09 10:31:54,345 - WARNING - No index fields found in MODEL_INPUT. Initializing index fields.
# 2025-06-09 10:31:54,345 - INFO - Successfully instantiated table MODEL_INPUT
# 2025-06-09 10:31:54,346 - WARNING - No index fields found in MODEL_OUTPUT. Initializing index fields.
# 2025-06-09 10:31:54,346 - INFO - Successfully instantiated table MODEL_OUTPUT
# 2025-06-09 10:31:54,347 - INFO - SISEPUEDEOutputDatabase successfully initialized IterativeDatabase.
# 2025-06-09 10:31:54,347 - INFO - Successfully initialized database with:
# 	type:	csv
# 	analysis id:	sisepuede_run_2025-06-09T10:31:53.405544
# 	fp_base_output:	/home/tony-ubuntu/anaconda3/envs/ssp_uganda/lib/python3.11/site-packages/sisepuede/out/sisepuede_run_2025-06-09T10;31;53.405544/sisepuede_run_2025-06-09T10;31;53.405544_output_database
# 2025-06-09 10:31:54,347 - INFO - Running SISEPUEDE under template data mode 'calibrated'.
# 2025-06-09 10:31:54,348 - INFO - Initializing BaseInputDatabase
# 2025-06-09 10:31:54,954 - INFO - Initializing FutureTrajectories
# 2025-06-09 10:31:58,949 - INFO - Instantiating 1502 sampling units.
# 2025-06-09 10:31:58,978 - INFO - Iteration 0 complete.
# 2025-06-09 10:32:04,910 - INFO - Iteration 250 complete.
# 2025-06-09 10:32:08,925 - INFO - Iteration 500 complete.
# 2025-06-09 10:32:12,660 - INFO - Iteration 750 complete.
# 2025-06-09 10:32:16,446 - INFO - Iteration 1000 complete.
# 2025-06-09 10:32:20,556 - INFO - Iteration 1250 complete.
# 2025-06-09 10:32:24,555 - INFO - Iteration 1500 complete.
# 2025-06-09 10:32:24,573 - INFO - 	1502 sampling units complete in 25.62 seconds.
# 2025-06-09 10:32:24,581 - INFO - 	FutureTrajectories for 'uganda' complete.
# 2025-06-09 10:32:24,582 - INFO - Initializing LHSDesign
# 2025-06-09 10:32:24,583 - INFO - LHSDesign.fields_factors_l reset successful.
# 2025-06-09 10:32:24,584 - INFO - LHSDesign.fields_factors_x reset successful.
# 2025-06-09 10:32:24,603 - INFO - 	LHSDesign for region 'uganda' complete.
# 2025-06-09 10:32:24,604 - INFO - Generating primary keys (values of primary_id)...
# 2025-06-09 10:32:24,605 - INFO - Successfully initialized SISEPUEDEExperimentalManager.
# 2025-06-09 10:32:24,606 - INFO - Successfully initialized NemoMod temporary database path as /home/tony-ubuntu/anaconda3/envs/ssp_uganda/lib/python3.11/site-packages/sisepuede/tmp/nemomod_intermediate_database.sqlite.
# 2025-06-09 10:32:24,606 - INFO - Set Julia directory for modules and environment to '/home/tony-ubuntu/anaconda3/envs/ssp_uganda/lib/python3.11/site-packages/sisepuede/julia'.
# 2025-06-09 10:32:24,701 - INFO - Successfully initialized SISEPUEDEModels.
# 2025-06-09 10:32:24,707 - INFO - Table ANALYSIS_METADATA successfully written to /home/tony-ubuntu/anaconda3/envs/ssp_uganda/lib/python3.11/site-packages/sisepuede/out/sisepuede_run_2025-06-09T10;31;53.405544/sisepuede_run_2025-06-09T10;31;53.405544_output_database/ANALYSIS_METADATA.csv.
# 2025-06-09 10:32:24,708 - INFO - Table ATTRIBUTE_DESIGN successfully written to /home/tony-ubuntu/anaconda3/envs/ssp_uganda/lib/python3.11/site-packages/sisepuede/out/sisepuede_run_2025-06-09T10;31;53.405544/sisepuede_run_2025-06-09T10;31;53.405544_output_database/ATTRIBUTE_DESIGN.csv.
# 2025-06-09 10:32:24,711 - INFO - Table ATTRIBUTE_STRATEGY successfully written to /home/tony-ubuntu/anaconda3/envs/ssp_uganda/lib/python3.11/site-packages/sisepuede/out/sisepuede_run_2025-06-09T10;31;53.405544/sisepuede_run_2025-06-09T10;31;53.405544_output_database/ATTRIBUTE_STRATEGY.csv.
# 2025-06-09 10:32:24,923 - INFO - Table MODEL_BASE_INPUT_DATABASE successfully written to /home/tony-ubuntu/anaconda3/envs/ssp_uganda/lib/python3.11/site-packages/sisepuede/out/sisepuede_run_2025-06-09T10;31;53.405544/sisepuede_run_2025-06-09T10;31;53.405544_output_database/MODEL_BASE_INPUT_DATABASE.csv.

# %%
# This runs the model, make sure you edit key_stretegy with the strategy ids you want to execute include baseline (0)
dict_scens = {
    ssp.key_design: [0],
    ssp.key_future: [0],
    ssp.key_strategy: strategies_to_run,
}

ssp.project_scenarios(
    dict_scens,
    save_inputs = True,
    include_electricity_in_energy = energy_model_flag
)
# Out:
# 2025-06-09 10:32:24,955 - INFO -
# ***	STARTING REGION uganda	***
#
# 2025-06-09 10:32:28,619 - INFO - Trying run primary_id = 0 in region uganda
# 2025-06-09 10:32:28,620 - INFO - Running AFOLU model
# 2025-06-09 10:32:28,842 - INFO - AFOLU model run successfully completed
# 2025-06-09 10:32:28,843 - INFO - Running CircularEconomy model
# 2025-06-09 10:32:28,915 - INFO - CircularEconomy model run successfully completed
# 2025-06-09 10:32:28,916 - INFO - Running IPPU model
# 2025-06-09 10:32:29,036 - INFO - IPPU model run successfully completed
# 2025-06-09 10:32:29,037 - INFO - Running Energy model (EnergyConsumption without Fugitive Emissions)
# 2025-06-09 10:32:29,084 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2025-06-09 10:32:29,194 - INFO - EnergyConsumption without Fugitive Emissions model run successfully completed
# 2025-06-09 10:32:29,195 - INFO - Running Energy (Fugitive Emissions)
# 2025-06-09 10:32:29,243 - ERROR - Error running Fugitive Emissions from Energy model: 'NoneType' object has no attribute 'to_numpy'
# 2025-06-09 10:32:29,243 - INFO - Appending Socioeconomic outputs
# 2025-06-09 10:32:29,263 - INFO - Socioeconomic outputs successfully appended.
# 2025-06-09 10:32:29,268 - INFO - Model run for primary_id = 0 successfully completed in 0.65 seconds (n_tries = 1).
# 2025-06-09 10:32:29,290 - INFO - Trying run primary_id = 69069 in region uganda
# 2025-06-09 10:32:29,291 - INFO - Running AFOLU model
# 2025-06-09 10:32:29,517 - INFO - AFOLU model run successfully completed
# 2025-06-09 10:32:29,518 - INFO - Running CircularEconomy model
# 2025-06-09 10:32:29,593 - INFO - CircularEconomy model run successfully completed
# 2025-06-09 10:32:29,594 - INFO - Running IPPU model
# 2025-06-09 10:32:29,718 - INFO - IPPU model run successfully completed
# 2025-06-09 10:32:29,719 - INFO - Running Energy model (EnergyConsumption without Fugitive Emissions)
# 2025-06-09 10:32:29,762 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2025-06-09 10:32:29,866 - INFO - EnergyConsumption without Fugitive Emissions model run successfully completed
# 2025-06-09 10:32:29,867 - INFO - Running Energy (Fugitive Emissions)
# 2025-06-09 10:32:29,926 - ERROR - Error running Fugitive Emissions from Energy model: 'NoneType' object has no attribute 'to_numpy'
# 2025-06-09 10:32:29,927 - INFO - Appending Socioeconomic outputs
# 2025-06-09 10:32:29,965 - INFO - Socioeconomic outputs successfully appended.
# 2025-06-09 10:32:29,971 - INFO - Model run for primary_id = 69069 successfully completed in 0.68 seconds (n_tries = 1).
# 2025-06-09 10:32:29,979 - INFO - Trying run primary_id = 70070 in region uganda
# 2025-06-09 10:32:29,981 - INFO - Running AFOLU model
# 2025-06-09 10:32:30,244 - INFO - AFOLU model run successfully completed
# 2025-06-09 10:32:30,245 - INFO - Running CircularEconomy model
# 2025-06-09 10:32:30,325 - INFO - CircularEconomy model run successfully completed
# 2025-06-09 10:32:30,326 - INFO - Running IPPU model
# 2025-06-09 10:32:30,445 - INFO - IPPU model run successfully completed
# 2025-06-09 10:32:30,446 - INFO - Running Energy model (EnergyConsumption without Fugitive Emissions)
# 2025-06-09 10:32:30,492 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2025-06-09 10:32:30,596 - INFO - EnergyConsumption without Fugitive Emissions model run successfully completed
# 2025-06-09 10:32:30,596 - INFO - Running Energy (Fugitive Emissions)
# 2025-06-09 10:32:30,648 - ERROR - Error running Fugitive Emissions from Energy model: 'NoneType' object has no attribute 'to_numpy'
# 2025-06-09 10:32:30,649 - INFO - Appending Socioeconomic outputs
# 2025-06-09 10:32:30,669 - INFO - Socioeconomic outputs successfully appended.
# 2025-06-09 10:32:30,673 - INFO - Model run for primary_id = 70070 successfully completed in 0.69 seconds (n_tries = 1).
# 2025-06-09 10:32:30,678 - INFO - Trying run primary_id = 71071 in region uganda
# 2025-06-09 10:32:30,679 - INFO - Running AFOLU model
# 2025-06-09 10:32:30,903 - INFO - AFOLU model run successfully completed
# 2025-06-09 10:32:30,904 - INFO - Running CircularEconomy model
# 2025-06-09 10:32:30,981 - INFO - CircularEconomy model run successfully completed
# 2025-06-09 10:32:30,982 - INFO - Running IPPU model
# 2025-06-09 10:32:31,110 - INFO - IPPU model run successfully completed
# 2025-06-09 10:32:31,111 - INFO - Running Energy model (EnergyConsumption without Fugitive Emissions)
# 2025-06-09 10:32:31,164 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2025-06-09 10:32:31,279 - INFO - EnergyConsumption without Fugitive Emissions model run successfully completed
# 2025-06-09 10:32:31,280 - INFO - Running Energy (Fugitive Emissions)
# 2025-06-09 10:32:31,328 - ERROR - Error running Fugitive Emissions from Energy model: 'NoneType' object has no attribute 'to_numpy'
# 2025-06-09 10:32:31,329 - INFO - Appending Socioeconomic outputs
# 2025-06-09 10:32:31,349 - INFO - Socioeconomic outputs successfully appended.
# 2025-06-09 10:32:31,353 - INFO - Model run for primary_id = 71071 successfully completed in 0.67 seconds (n_tries = 1).
# 2025-06-09 10:32:31,356 - INFO -
# ***	 REGION uganda COMPLETE	***
#
# 2025-06-09 10:32:31,474 - INFO - Table MODEL_OUTPUT successfully written to /home/tony-ubuntu/anaconda3/envs/ssp_uganda/lib/python3.11/site-packages/sisepuede/out/sisepuede_run_2025-06-09T10;31;53.405544/sisepuede_run_2025-06-09T10;31;53.405544_output_database/MODEL_OUTPUT.csv.
# 2025-06-09 10:32:31,478 - INFO - Table ATTRIBUTE_PRIMARY successfully written to /home/tony-ubuntu/anaconda3/envs/ssp_uganda/lib/python3.11/site-packages/sisepuede/out/sisepuede_run_2025-06-09T10;31;53.405544/sisepuede_run_2025-06-09T10;31;53.405544_output_database/ATTRIBUTE_PRIMARY.csv.
# 2025-06-09 10:32:31,660 - INFO - Table MODEL_INPUT successfully written to /home/tony-ubuntu/anaconda3/envs/ssp_uganda/lib/python3.11/site-packages/sisepuede/out/sisepuede_run_2025-06-09T10;31;53.405544/sisepuede_run_2025-06-09T10;31;53.405544_output_database/MODEL_INPUT.csv.
# {'uganda': [0, 69069, 70070, 71071]}

# %%
# Read input and output files
df_out = ssp.read_output(None)
df_in = ssp.read_input(None)

# %% [markdown]
# ## Let's Explore the Results

# %%
def plot_field_stack(
    df,
    fields,
    dict_format,
    time_col="time_period",
    primary_id=0,
    figsize=(18, 8),
    legend_loc='upper right',
    legend_bbox=(1.1, 1),
    ylabel="MT Emissions CO2e",
    xlabel="Time Period",
    title=None,
):
    """
    Plots a stack plot of the selected fields for a given primary_id.

    Args:
        df (pd.DataFrame): DataFrame containing output data.
        fields (list): List of column names to plot.
        dict_format (dict): Formatting dictionary for colors.
        time_col (str): Name of the time column.
        primary_id (int): Value of primary_id to filter.
        figsize (tuple): Figure size.
        legend_loc (str): Legend location.
        legend_bbox (tuple): Legend bbox_to_anchor.
        ylabel (str): Y-axis label.
        xlabel (str): X-axis label.
        title (str): Plot title.
    """
    fig, ax = plt.subplots(figsize=figsize)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    if title:
        ax.set_title(title)

    df_plot = df[df[ssp.key_primary].isin([primary_id])]

    fig, ax = spu.plot_stack(
        df_plot,
        fields,
        dict_formatting=dict_format,
        field_x=time_col,
        figtuple=(fig, ax),
    )

    ax.legend(loc=legend_loc, bbox_to_anchor=legend_bbox, title="Fields")
    plt.show()

# %%
# Define the fields to plot and the formatting dictionary
subsector_emission_fields = [
'emission_co2e_subsector_total_agrc',
 'emission_co2e_subsector_total_frst',
 'emission_co2e_subsector_total_lndu',
 'emission_co2e_subsector_total_lsmm',
 'emission_co2e_subsector_total_lvst',
 'emission_co2e_subsector_total_soil',
 'emission_co2e_subsector_total_waso',
 'emission_co2e_subsector_total_trww',
 'emission_co2e_subsector_total_ippu']

dict_format = dict(
    (k, {"color": v}) for (k, v) in
    matt.get_subsector_color_map().items()
)

# %%
# Plot the emissions stack for the primary_id 0 (which is the baseline)
plot_field_stack(
    df_out,
    subsector_emission_fields,
    dict_format,
    primary_id=0,
    title="Emissions Stack Plot for Baseline (Primary ID 0)"
)

# %%
# Plot the emissions stack for the primary_id 71071 (which is the BAU strategy)
plot_field_stack(
    df_out,
    subsector_emission_fields,
    dict_format,
    primary_id=71071,
    title="Emissions Stack Plot for BAU Strategy (Primary ID 71071)"
)

# %%
# Plot the emissions stack for the primary_id 69069 (which is the NDC strategy)
plot_field_stack(
    df_out,
    subsector_emission_fields,
    dict_format,
    primary_id=69069,
    title="Emissions Stack Plot for NDC Strategy (Primary ID 69069)"
)

# %%
# Plot the emission stack for the primary_id 70070 (which is the Net Zero strategy)
plot_field_stack(
    df_out,
    subsector_emission_fields,
    dict_format,
    primary_id=70070,
    title="Emissions Stack Plot for Net Zero Strategy (Primary ID 70070)"
)

# %%
lndu_fields = [
    'area_lndu_croplands',
    'area_lndu_forests_mangroves', 'area_lndu_forests_primary',
    'area_lndu_forests_secondary', 'area_lndu_grasslands',
    'area_lndu_improved_croplands', 'area_lndu_improved_grasslands',
    'area_lndu_other', 'area_lndu_settlements', 'area_lndu_wetlands'
]

# Plot the land use area stack for the primary_id 0 (which is the baseline)
plot_field_stack(
    df_out,
    lndu_fields,
    dict_format,
    primary_id=0,
    title="Land Use Area Stack Plot for Baseline (Primary ID 0)",
    ylabel="Land Area (Units)",
    xlabel="Time Period",
)

# %%
# Plot the land use area stack for the primary_id 71071 (which is the BAU strategy)
plot_field_stack(
    df_out,
    lndu_fields,
    dict_format,
    primary_id=71071,
    title="Land Use Area Stack Plot for BAU Strategy (Primary ID 71071)",
    ylabel="Land Area (Units)",
    xlabel="Time Period",
)

# %%
# Plot the land use area stack for the primary_id 69069 (which is the NDC strategy)
plot_field_stack(
    df_out,
    lndu_fields,
    dict_format,
    primary_id=69069,
    title="Land Use Area Stack Plot for NDC Strategy (Primary ID 69069)",
    ylabel="Land Area (Units)",
    xlabel="Time Period",
)

# %%
# Plot the lndu area stack for the primary_id 70070 (which is the Net Zero strategy)
plot_field_stack(
    df_out,
    lndu_fields,
    dict_format,
    primary_id=70070,
    title="Land Use Area Stack Plot for Net Zero Strategy (Primary ID 70070)",
    ylabel="Land Area (Units)",
    xlabel="Time Period",
)

# %% [markdown]
# # Export Wide File (Last Mandatory Step)

# %%
df_out = ssp.read_output(None)
df_in = ssp.read_input(None)


all_primaries = sorted(list(df_out[ssp.key_primary].unique()))

# build if unable to simply read the data frame
if df_in is None:
    df_in = []
     
    for region in ssp.regions:
        for primary in all_primaries: 
            df_in_filt = ssp.generate_scenario_database_from_primary_key(primary)
            df_in.append(df_in_filt.get(region))
    
    df_in = pd.concat(df_in, axis = 0).reset_index(drop = True)




df_export = pd.merge(
    df_out,
    df_in,
    how = "left",
)



# check output directory 
dir_pkg = os.path.join(
    ssp.file_struct.dir_out, 
    f"sisepuede_summary_results_run_{ssp.id_fs_safe}"
)
os.makedirs(dir_pkg) if not os.path.exists(dir_pkg) else None


for tab in ["ATTRIBUTE_STRATEGY"]:
    table_df = ssp.database.db.read_table(tab)
    if table_df is not None:
        table_df.to_csv(
            os.path.join(dir_pkg, f"{tab}.csv"),
            index=None,
            encoding="UTF-8"
        )
    else:
        print(f"Warning: Table {tab} returned None.")


df_primary = (
    ssp
    .odpt_primary
    .get_indexing_dataframe(
        sorted(list(df_out[ssp.key_primary].unique()))
    )
)
    
df_primary.to_csv(
    os.path.join(dir_pkg, f"ATTRIBUTE_PRIMARY.csv"),
    index = None,
    encoding = "UTF-8"
)

df_export.to_csv(
    os.path.join(dir_pkg, f"sisepuede_results_{ssp.id_fs_safe}_WIDE_INPUTS_OUTPUTS.csv"),
    index = None,
    encoding = "UTF-8"
)

# %%
# Getting the directory where the outputs are stored
ssp.file_struct.dir_out
# Out:
# '/home/tony-ubuntu/anaconda3/envs/ssp_uganda/lib/python3.11/site-packages/sisepuede/out'

# %%
df_primary.to_csv(
    os.path.join(dir_out, f"ATTRIBUTE_PRIMARY.csv"),
    index = None,
    encoding = "UTF-8"
)

df_export.to_csv(
    os.path.join(dir_out, f"sisepuede_results_sisepuede_bau_run.csv"),
    index = None,
    encoding = "UTF-8"
)

for tab in ["ATTRIBUTE_STRATEGY"]:
    table_df = ssp.database.db.read_table(tab)
    if table_df is not None:
        table_df.to_csv(
            os.path.join(dir_out, f"{tab}.csv"),
            index=None,
            encoding="UTF-8"
        )
    else:
        print(f"Warning: Table {tab} returned None.")
